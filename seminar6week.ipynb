# %%
#1
lst = []
n = int(input("Enter number of elements : "))
for i in range(0, n ):
        for j in range (0, i+1):
            print("*", end=" ")
        print("\r")
# Out:
# Enter number of elements : 4
# *
# * *
# * * *
# * * * *

# %%
#1
n = int(input("Enter number of elements : "))
for i in range(0, n):
        for j in range (0, i+1):
            print("*", end=" ")
        print("\r")
# Out:
# Enter number of elements : 5
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
#3
dict1={
    'Bat':18,
    'Oyun':22,
    'Dulam':21,
    'Suren':20
}
key_max = max(dict1.keys(), key=(lambda k: dict1[k]))
key_min = min(dict1.keys(), key=(lambda k: dict1[k]))

print('Maximum Value: ',dict1.get(key_max))
print('Minimum Value: ',dict1.get(key_min))
# Out:
# Maximum Value:  22
# Minimum Value:  18

# %%
#3
your_dictionary={
    'Bat':18,
    'Oyun':22,
    'Dulam':21,
    'Suren':20
}

new_maximum_val = max(your_dictionary.keys(), key=(lambda new_k: your_dictionary[new_k]))
print('Maximum Value: ',your_dictionary[new_maximum_val])
new_minimum_val = min(your_dictionary.keys(), key=(lambda new_k: your_dictionary[new_k]))
print('Minimum Value: ',your_dictionary[new_minimum_val])
# Out:
# Maximum Value:  22
# Minimum Value:  18

# %%
# Out:
# Sum =  499500

# %%
#3
dict1={
    'Bat':18,
    'Oyun':22,
    'Dulam':21,
    'Suren':20
}


best_key = min(dict1, key=dict1.get)
best_key1 = max(dict1, key=dict1.get)
print(best_key)
print(best_key1)
# Out:
# Bat
# Oyun

# %%
#4
sum=0
import numpy as np
data1=np.arange(1000)
arr1=np.array(data1)
arr1
for i in range(1000):
    if (i % 3 == 0 and i % 7 == 0):
        print(i)
        
        sum += int (i)
print("Sum = ",sum)
# Out:
# 0
# 21
# 42
# 63
# 84
# 105
# 126
# 147
# 168
# 189
# 210
# 231
# 252
# 273
# 294
# 315
# 336
# 357
# 378
# 399
# 420
# 441
# 462
# 483
# 504
# 525
# 546
# 567
# 588
# 609
# 630
# 651
# 672
# 693
# 714
# 735
# 756
# 777
# 798
# 819
# 840
# 861
# 882
# 903
# 924
# 945
# 966
# 987
# Sum =  23688

# %%
#4
sum=0
import numpy as np
data1=np.arange(1000)
arr1=np.array(data1)
arr1
for i in range(1000):
    if (i % 3 == 0 or i % 7 == 0):
        print(i)
        
        sum += int (i)
print("Sum = ",sum)
# Out:
# 0
# 3
# 6
# 7
# 9
# 12
# 14
# 15
# 18
# 21
# 24
# 27
# 28
# 30
# 33
# 35
# 36
# 39
# 42
# 45
# 48
# 49
# 51
# 54
# 56
# 57
# 60
# 63
# 66
# 69
# 70
# 72
# 75
# 77
# 78
# 81
# 84
# 87
# 90
# 91
# 93
# 96
# 98
# 99
# 102
# 105
# 108
# 111
# 112
# 114
# 117
# 119
# 120
# 123
# 126
# 129
# 132
# 133
# 135
# 138
# 140
# 141
# 144
# 147
# 150
# 153
# 154
# 156
# 159
# 161
# 162
# 165
# 168
# 171
# 174
# 175
# 177
# 180
# 182
# 183
# 186
# 189
# 192
# 195
# 196
# 198
# 201
# 203
# 204
# 207
# 210
# 213
# 216
# 217
# 219
# 222
# 224
# 225
# 228
# 231
# 234
# 237
# 238
# 240
# 243
# 245
# 246
# 249
# 252
# 255
# 258
# 259
# 261
# 264
# 266
# 267
# 270
# 273
# 276
# 279
# 280
# 282
# 285
# 287
# 288
# 291
# 294
# 297
# 300
# 301
# 303
# 306
# 308
# 309
# 312
# 315
# 318
# 321
# 322
# 324
# 327
# 329
# 330
# 333
# 336
# 339
# 342
# 343
# 345
# 348
# 350
# 351
# 354
# 357
# 360
# 363
# 364
# 366
# 369
# 371
# 372
# 375
# 378
# 381
# 384
# 385
# 387
# 390
# 392
# 393
# 396
# 399
# 402
# 405
# ...

# %%
# Out:
# Enter number of elements : 5
#
# Enter the numbers : 6
#
# List is -  [6]
